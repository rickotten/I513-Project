# %% [markdown]
# # Project Selection Report on Cryptocurrency Historical Prices
#
# Team Members: Richard Otten, Blake Hoekstra, Caleb Wilson, Mason Culley
#
# Subject of Focus: CryptoMarket Analysis
#
# Link: https://www.kaggle.com/sudalairajkumar/cryptocurrencypricehistory
#
# As a group we decided upon using the above data set found on Kaggle to research and analyze. This dataset includes information about the historical prices of multiple cryptocurrencies.

# %% [markdown]
# ## Cryptocurrencies
#
# First here is a short description of what cryptocurrencies are:
#
# A cryptocurrency is a digital currency and asset that is kept track of using a technology known as blockchain. Blockchain is most commonly used as a virtual ledger that keeps track of and records transactions with a cryptocurrency. It is generally considered highly secure as it does not allow counterfeiting and resolves many other issues that arise from the usage of physical currencies. Another appeal of it to many is that cryptocurencies are not associated with any government and therefore can not be manipulated or interfered with by them.
#
# Cryptocurrencies can be used to purchase the same things you would purchase with any other form of currency. Recently however what people have really been interested in is investing in cryptocurrencies in the same way that people invest in other stocks or goods such as oil and precious metals as it is a very lucrative and expanding market. Many investors would describe the cryptocurrency market as volatile and high-risk and our goal with this dataset is to try and recognize these trends and shifts that causes the cryptocurrency market to be classified in this way.

# %% [markdown]
# ## The Dataset
#
# Shifting back to our report, the cryptocurrencies included in this dataset are:
#
# - Aave (AAVE)
# - Binance Coin (BNB)
# - Bitcoin (BTC)
# - Cardano (ADA)
# - Chainlink (LINK)
# - Cosmos (ATOM)
# - Crypto.com Coin (CRO)
# - Dogecoin (DOGE)
# - EOS (EOS)
# - Ethereum (ETH)
# - Iota (MIOTA)
# - Litecoin (LTC)
# - Monero (XMR)
# - NEM (XEM)
# - Polkadot (DOT)
# - Solana (SOL)
# - Stellar (XLM)
# - Tether (USDT)
# - Tron (TRX)
# - USD Coin (USDC)
# - Uniswap (UNI)
# - Wrapped Bitcoin (WBTC)
# - XRP (XRP)
#
# Each cryptocurrency has their own CSV file containing the following associated data as fields:
#
# - SNo : (serial number) this is the primary ID
# - Name : Name of the cryptocurrency
# - Symbol : The given cryptocurrencies stock ticker symbol
# - Date : Date of observation
# - High : Highest price on the given day
# - Low : Lowest price on the given day
# - Open : Opening price on the given day
# - Close : Closing price on the given day
# - Volume : Volume of transactions on the given day
# - Marketcap : Market capitalization in USD
#
# Our plans with this data is to analyze and process it in order to try to make sense of how cryptocurrency prices fluctuate. There are trends in the fluctuations that may be possible to identify. We would like to be able to plausibly explain how and why these trends happen, when they happen, and then come up with a way to predict the price based off of the conclusions we come to.

# %% [markdown]
# # Gathering Data
# We processed and cleaned our data with csv’s, pandas, and data frame structures. We downloaded the attatched DataSet from Kaggle.com.
#
# We first uploaded a zip of all the csvs into google colab. Then we unzipped the archive with this code:

# %%
# Use this to unzip an uploaded archive
# !unzip /content/archive.zip
# Out:
# Archive:  /content/archive.zip
#   inflating: coin_Aave.csv
#   inflating: coin_BinanceCoin.csv
#   inflating: coin_Bitcoin.csv
#   inflating: coin_Cardano.csv
#   inflating: coin_ChainLink.csv
#   inflating: coin_Cosmos.csv
#   inflating: coin_CryptocomCoin.csv
#   inflating: coin_Dogecoin.csv
#   inflating: coin_EOS.csv
#   inflating: coin_Ethereum.csv
#   inflating: coin_Iota.csv
#   inflating: coin_Litecoin.csv
#   inflating: coin_Monero.csv
#   inflating: coin_NEM.csv
#   inflating: coin_Polkadot.csv
#   inflating: coin_Solana.csv
#   inflating: coin_Stellar.csv
#   inflating: coin_Tether.csv
#   inflating: coin_Tron.csv
#   inflating: coin_USDCoin.csv
#   inflating: coin_Uniswap.csv
#   inflating: coin_WrappedBitcoin.csv
#   inflating: coin_XRP.csv

# %% [markdown]
# # Gather all CSVs
# Then we created a list of csv file names for automation:

# %%
import os
files = []
for filename in os.listdir(os.getcwd()):
  if filename[-3:] == "csv":
    files += [filename]
print(files)
# Out:
# ['coin_Stellar.csv', 'coin_EOS.csv', 'coin_Cardano.csv', 'coin_Aave.csv', 'coin_NEM.csv', 'coin_Ethereum.csv', 'coin_Cosmos.csv', 'coin_Polkadot.csv', 'coin_WrappedBitcoin.csv', 'coin_Tether.csv', 'coin_Uniswap.csv', 'coin_CryptocomCoin.csv', 'coin_XRP.csv', 'coin_Tron.csv', 'coin_Monero.csv', 'coin_Solana.csv', 'coin_BinanceCoin.csv', 'coin_Iota.csv', 'coin_ChainLink.csv', 'coin_Dogecoin.csv', 'coin_Bitcoin.csv', 'coin_Litecoin.csv', 'coin_USDCoin.csv']

# %% [markdown]
# # Descriptions and Initial Statistics of Datasets

# %% [markdown]
# Next we used pandas read_csv  command to turn the csv files into a data frame. Then we used pandas .describe()  method to print out summary statistics. We used pandas .datatypes command to print out the data types of the data fields.

# %%
import pandas as pd
import numpy as np

#print out file name, data types, and summary statistics
for f in files:
  df = pd.read_csv(f)
  print(f)
  print('Data Types:')
  print(df.dtypes)
  print('\n')
  print('Statistical Descriptions:')
  print(df.describe())
  print('\n')
# Out:
# coin_Stellar.csv
# Data Types:
# SNo            int64
# Name          object
# Symbol        object
# Date          object
# High         float64
# Low          float64
# Open         float64
# Close        float64
# Volume       float64
# Marketcap    float64
# dtype: object
#
#
# Statistical Descriptions:
#                SNo         High  ...        Volume     Marketcap
# count  2398.000000  2398.000000  ...  2.398000e+03  2.398000e+03
# mean   1199.500000     0.087763  ...  1.787830e+08  1.590467e+09
# std     692.387295     0.125602  ...  4.834222e+08  2.278837e+09
# min       1.000000     0.001509  ...  4.910920e+02  9.663695e+05
# 25%     600.250000     0.002495  ...  4.307210e+04  1.239882e+07
# 50%    1199.500000     0.043371  ...  3.358515e+07  6.580054e+08
# 75%    1798.750000     0.108561  ...  1.905707e+08  2.077972e+09
# max    2398.000000     0.938144  ...  1.040858e+10  1.602204e+10
#
# [8 rows x 7 columns]
#
#
# coin_EOS.csv
# Data Types:
# SNo            int64
# ...

# %% [markdown]
# # Basic Visualizations
# We provide the following rough visualizations of basic trends in our dataset. Such trends include Highs vs Lows and Volume vs Market Cap (trends of interest to the consumer). While these are basic, it provides insight into initial patterns and trends we might consider exploring.

# %%
# Highs vs Lows over time
import matplotlib.pyplot as plt
import matplotlib.dates as mdates

for f in files:
  df = pd.read_csv(f, parse_dates=["Date"])
  ax = df.plot(x="Date", y=["High", "Low"])
  ax.xaxis.set_major_formatter(mdates.DateFormatter("%Y-%m-%d"))
  ax.xaxis.set_minor_formatter(mdates.DateFormatter("%Y-%m-%d"))
  ax.set_title(f[:-4].split("_")[1])

  
plt.show()
# Out:
# /usr/local/lib/python3.7/dist-packages/pandas/plotting/_matplotlib/core.py:328: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   fig = self.plt.figure(figsize=self.figsize)
# /usr/local/lib/python3.7/dist-packages/pandas/plotting/_matplotlib/core.py:328: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   fig = self.plt.figure(figsize=self.figsize)
# ...

# %%
# MarketCap vs Volume over time
for f in files:
  df = pd.read_csv(f, parse_dates=["Date"])
  ax = df.plot(x="Date", y=["Marketcap", "Volume"])
  ax.xaxis.set_major_formatter(mdates.DateFormatter("%Y-%m-%d"))
  ax.xaxis.set_minor_formatter(mdates.DateFormatter("%Y-%m-%d"))
  ax.set_title(f[:-4].split("_")[1])

  
plt.show()
# Out:
# /usr/local/lib/python3.7/dist-packages/pandas/plotting/_matplotlib/core.py:328: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   fig = self.plt.figure(figsize=self.figsize)
# /usr/local/lib/python3.7/dist-packages/pandas/plotting/_matplotlib/core.py:328: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   fig = self.plt.figure(figsize=self.figsize)
# ...

# %% [markdown]
# The initial thoughts gathered from the above lead us to ask:
#
# * Are we able to predict future crypto price points based on previous crypto price trends and cycles?
#
# * What kind of user interface and user experience do we want to have for our program?
#
# * What kinds of graphs and chart  visualizations do we want to use and what will be best?
#
# * What kind of algorithms and cookbooks do we want to use for predicting future price trends in cryptocurrency?
